# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#to init a neural netwok
from keras.models import Sequential
#to add convulation layer
from keras.layers import Conv2D
#to making pooling
from keras.layers import MaxPooling2D
#to flattening
from keras.layers import Flatten
#to create hidden node
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
seq=Sequential()
seq.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
seq.add(MaxPooling2D((2, 2)))
seq.add(Flatten())
seq.add(Dense(128, activation='relu'))
seq.add(Dense(1,activation='sigmoid'))
seq.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
        'dataset/training_set/',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
test_set = test_datagen.flow_from_directory(
        'dataset/test_set',
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
# checkpoint
from keras.callbacks import ModelCheckpoint
filepath="weights-improvement.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
seq.fit_generator(
        training_set,
        steps_per_epoch=80,
        epochs=25,
        validation_data=test_set,
        validation_steps=20,
        callbacks=callbacks_list)
# Out:
# Epoch 1/25
# 80/80 [==============================] - 84s 1s/step - loss: 0.6506 - accuracy: 0.6258 - val_loss: 0.6821 - val_accuracy: 0.6766
#
# Epoch 00001: val_accuracy improved from -inf to 0.67656, saving model to weights-improvement.hdf5
# Epoch 2/25
# 80/80 [==============================] - 81s 1s/step - loss: 0.6236 - accuracy: 0.6590 - val_loss: 0.8296 - val_accuracy: 0.7109
#
# Epoch 00002: val_accuracy improved from 0.67656 to 0.71094, saving model to weights-improvement.hdf5
# Epoch 3/25
# 80/80 [==============================] - 74s 930ms/step - loss: 0.5935 - accuracy: 0.6750 - val_loss: 0.7037 - val_accuracy: 0.6703
#
# Epoch 00003: val_accuracy did not improve from 0.71094
# Epoch 4/25
# 80/80 [==============================] - 22s 279ms/step - loss: 0.5931 - accuracy: 0.6969 - val_loss: 0.5381 - val_accuracy: 0.6923
#
# Epoch 00004: val_accuracy did not improve from 0.71094
# Epoch 5/25
# 80/80 [==============================] - 20s 256ms/step - loss: 0.5677 - accuracy: 0.6977 - val_loss: 0.5701 - val_accuracy: 0.7125
#
# Epoch 00005: val_accuracy improved from 0.71094 to 0.71250, saving model to weights-improvement.hdf5
# Epoch 6/25
# 80/80 [==============================] - 21s 265ms/step - loss: 0.5806 - accuracy: 0.6906 - val_loss: 0.7443 - val_accuracy: 0.7047
#
# Epoch 00006: val_accuracy did not improve from 0.71250
# Epoch 7/25
# 80/80 [==============================] - 22s 280ms/step - loss: 0.5633 - accuracy: 0.7082 - val_loss: 0.6172 - val_accuracy: 0.7099
#
# Epoch 00007: val_accuracy did not improve from 0.71250
# Epoch 8/25
# 80/80 [==============================] - 21s 259ms/step - loss: 0.5532 - accuracy: 0.7125 - val_loss: 0.4898 - val_accuracy: 0.7188
#
# Epoch 00008: val_accuracy improved from 0.71250 to 0.71875, saving model to weights-improvement.hdf5
# Epoch 9/25
# 80/80 [==============================] - 21s 266ms/step - loss: 0.5547 - accuracy: 0.7121 - val_loss: 0.5105 - val_accuracy: 0.7516
#
# Epoch 00009: val_accuracy improved from 0.71875 to 0.75156, saving model to weights-improvement.hdf5
# Epoch 10/25
# 80/80 [==============================] - 22s 274ms/step - loss: 0.5343 - accuracy: 0.7277 - val_loss: 0.4009 - val_accuracy: 0.6603
#
# Epoch 00010: val_accuracy did not improve from 0.75156
# Epoch 11/25
# 80/80 [==============================] - 21s 262ms/step - loss: 0.5343 - accuracy: 0.7328 - val_loss: 0.5609 - val_accuracy: 0.7547
#
# Epoch 00011: val_accuracy improved from 0.75156 to 0.75469, saving model to weights-improvement.hdf5
# Epoch 12/25
# 80/80 [==============================] - 22s 270ms/step - loss: 0.5367 - accuracy: 0.7254 - val_loss: 0.6200 - val_accuracy: 0.6906
#
# Epoch 00012: val_accuracy did not improve from 0.75469
# Epoch 13/25
# 80/80 [==============================] - 22s 270ms/step - loss: 0.5220 - accuracy: 0.7496 - val_loss: 0.5326 - val_accuracy: 0.7324
#
# Epoch 00013: val_accuracy did not improve from 0.75469
# Epoch 14/25
# 80/80 [==============================] - 22s 272ms/step - loss: 0.5151 - accuracy: 0.7477 - val_loss: 0.5513 - val_accuracy: 0.7375
#
# Epoch 00014: val_accuracy did not improve from 0.75469
# Epoch 15/25
# 80/80 [==============================] - 22s 272ms/step - loss: 0.5059 - accuracy: 0.7504 - val_loss: 0.4486 - val_accuracy: 0.7422
#
# Epoch 00015: val_accuracy did not improve from 0.75469
# Epoch 16/25
# 80/80 [==============================] - 22s 271ms/step - loss: 0.5216 - accuracy: 0.7410 - val_loss: 0.6178 - val_accuracy: 0.6955
#
# Epoch 00016: val_accuracy did not improve from 0.75469
# Epoch 17/25
# 80/80 [==============================] - 22s 273ms/step - loss: 0.5109 - accuracy: 0.7441 - val_loss: 0.3968 - val_accuracy: 0.7453
#
# Epoch 00017: val_accuracy did not improve from 0.75469
# Epoch 18/25
# 80/80 [==============================] - 22s 270ms/step - loss: 0.5212 - accuracy: 0.7367 - val_loss: 0.4376 - val_accuracy: 0.7453
#
# Epoch 00018: val_accuracy did not improve from 0.75469
# Epoch 19/25
# 80/80 [==============================] - 21s 268ms/step - loss: 0.5253 - accuracy: 0.7410 - val_loss: 0.4925 - val_accuracy: 0.7244
#
# Epoch 00019: val_accuracy did not improve from 0.75469
# Epoch 20/25
# 80/80 [==============================] - 22s 272ms/step - loss: 0.4886 - accuracy: 0.7605 - val_loss: 0.4233 - val_accuracy: 0.7203
#
# Epoch 00020: val_accuracy did not improve from 0.75469
# Epoch 21/25
# 80/80 [==============================] - 21s 268ms/step - loss: 0.4825 - accuracy: 0.7656 - val_loss: 0.3281 - val_accuracy: 0.7625
#
# Epoch 00021: val_accuracy improved from 0.75469 to 0.76250, saving model to weights-improvement.hdf5
# Epoch 22/25
# 80/80 [==============================] - 22s 271ms/step - loss: 0.5089 - accuracy: 0.7535 - val_loss: 0.6516 - val_accuracy: 0.7328
#
# Epoch 00022: val_accuracy did not improve from 0.76250
# Epoch 23/25
# 80/80 [==============================] - 23s 284ms/step - loss: 0.4775 - accuracy: 0.7750 - val_loss: 0.5091 - val_accuracy: 0.7404
#
# Epoch 00023: val_accuracy did not improve from 0.76250
# Epoch 24/25
# 80/80 [==============================] - 20s 252ms/step - loss: 0.4893 - accuracy: 0.7656 - val_loss: 0.3917 - val_accuracy: 0.7781
#
# Epoch 00024: val_accuracy improved from 0.76250 to 0.77812, saving model to weights-improvement.hdf5
# Epoch 25/25
# 80/80 [==============================] - 21s 268ms/step - loss: 0.5038 - accuracy: 0.7488 - val_loss: 0.4775 - val_accuracy: 0.7484
#
# Epoch 00025: val_accuracy did not improve from 0.77812

# %%
seq.fit_generator(
        training_set,
        steps_per_epoch=80,
        epochs=25,
        validation_data=test_set,
        validation_steps=20,
        callbacks=callbacks_list)
# Out:
# Epoch 1/25
# 80/80 [==============================] - 23s 285ms/step - loss: 0.4597 - accuracy: 0.7828 - val_loss: 0.4275 - val_accuracy: 0.7312
#
# Epoch 00001: val_accuracy did not improve from 0.77812
# Epoch 2/25
# 80/80 [==============================] - 22s 271ms/step - loss: 0.4937 - accuracy: 0.7527 - val_loss: 0.4867 - val_accuracy: 0.7063
#
# Epoch 00002: val_accuracy did not improve from 0.77812
# Epoch 3/25
# 80/80 [==============================] - 21s 268ms/step - loss: 0.4902 - accuracy: 0.7414 - val_loss: 0.3492 - val_accuracy: 0.7578
#
# Epoch 00003: val_accuracy did not improve from 0.77812
# Epoch 4/25
# 80/80 [==============================] - 23s 286ms/step - loss: 0.4411 - accuracy: 0.7949 - val_loss: 0.4692 - val_accuracy: 0.7580
#
# Epoch 00004: val_accuracy did not improve from 0.77812
# Epoch 5/25
# 80/80 [==============================] - 20s 252ms/step - loss: 0.4936 - accuracy: 0.7492 - val_loss: 0.6482 - val_accuracy: 0.7328
#
# Epoch 00005: val_accuracy did not improve from 0.77812
# Epoch 6/25
# 80/80 [==============================] - 21s 267ms/step - loss: 0.4884 - accuracy: 0.7508 - val_loss: 0.3587 - val_accuracy: 0.7469
#
# Epoch 00006: val_accuracy did not improve from 0.77812
# Epoch 7/25
# 80/80 [==============================] - 23s 285ms/step - loss: 0.4667 - accuracy: 0.7727 - val_loss: 0.7935 - val_accuracy: 0.7163
#
# Epoch 00007: val_accuracy did not improve from 0.77812
# Epoch 8/25
# 80/80 [==============================] - 21s 262ms/step - loss: 0.4722 - accuracy: 0.7676 - val_loss: 0.6204 - val_accuracy: 0.7484
#
# Epoch 00008: val_accuracy did not improve from 0.77812
# Epoch 9/25
# 80/80 [==============================] - 22s 276ms/step - loss: 0.4453 - accuracy: 0.7820 - val_loss: 0.4097 - val_accuracy: 0.7750
#
# Epoch 00009: val_accuracy did not improve from 0.77812
# Epoch 10/25
# 80/80 [==============================] - 21s 262ms/step - loss: 0.4343 - accuracy: 0.7996 - val_loss: 0.4474 - val_accuracy: 0.7564
#
# Epoch 00010: val_accuracy did not improve from 0.77812
# Epoch 11/25
# 80/80 [==============================] - 21s 261ms/step - loss: 0.4411 - accuracy: 0.7895 - val_loss: 0.8010 - val_accuracy: 0.7422
#
# Epoch 00011: val_accuracy did not improve from 0.77812
# Epoch 12/25
# 80/80 [==============================] - 22s 273ms/step - loss: 0.4535 - accuracy: 0.7707 - val_loss: 0.4556 - val_accuracy: 0.7703
#
# Epoch 00012: val_accuracy did not improve from 0.77812
# Epoch 13/25
# 80/80 [==============================] - 21s 261ms/step - loss: 0.4154 - accuracy: 0.8113 - val_loss: 0.9603 - val_accuracy: 0.6795
#
# Epoch 00013: val_accuracy did not improve from 0.77812
# Epoch 14/25
# 80/80 [==============================] - 22s 275ms/step - loss: 0.4324 - accuracy: 0.8055 - val_loss: 0.4270 - val_accuracy: 0.7937
#
# Epoch 00014: val_accuracy improved from 0.77812 to 0.79375, saving model to weights-improvement.hdf5
# Epoch 15/25
# 80/80 [==============================] - 22s 272ms/step - loss: 0.4575 - accuracy: 0.7828 - val_loss: 0.5241 - val_accuracy: 0.7750
#
# Epoch 00015: val_accuracy did not improve from 0.79375
# Epoch 16/25
# 80/80 [==============================] - 21s 268ms/step - loss: 0.4436 - accuracy: 0.7891 - val_loss: 0.3645 - val_accuracy: 0.7772
#
# Epoch 00016: val_accuracy did not improve from 0.79375
# Epoch 17/25
# 80/80 [==============================] - 22s 272ms/step - loss: 0.4188 - accuracy: 0.8004 - val_loss: 0.5143 - val_accuracy: 0.7797
#
# Epoch 00017: val_accuracy did not improve from 0.79375
# Epoch 18/25
# 80/80 [==============================] - 23s 283ms/step - loss: 0.4430 - accuracy: 0.8047 - val_loss: 0.1885 - val_accuracy: 0.7453
#
# Epoch 00018: val_accuracy did not improve from 0.79375
# Epoch 19/25
# 80/80 [==============================] - 22s 276ms/step - loss: 0.4193 - accuracy: 0.8062 - val_loss: 0.6164 - val_accuracy: 0.7869
#
# Epoch 00019: val_accuracy did not improve from 0.79375
# Epoch 20/25
# 80/80 [==============================] - 24s 299ms/step - loss: 0.4149 - accuracy: 0.8023 - val_loss: 0.4158 - val_accuracy: 0.7953
#
# Epoch 00020: val_accuracy improved from 0.79375 to 0.79531, saving model to weights-improvement.hdf5
# Epoch 21/25
# 80/80 [==============================] - 21s 263ms/step - loss: 0.4222 - accuracy: 0.8047 - val_loss: 0.4688 - val_accuracy: 0.7781
#
# Epoch 00021: val_accuracy did not improve from 0.79531
# Epoch 22/25
# 80/80 [==============================] - 22s 273ms/step - loss: 0.3954 - accuracy: 0.8180 - val_loss: 0.4868 - val_accuracy: 0.7500
#
# Epoch 00022: val_accuracy did not improve from 0.79531
# Epoch 23/25
# 80/80 [==============================] - 103s 1s/step - loss: 0.3916 - accuracy: 0.8117 - val_loss: 0.4862 - val_accuracy: 0.7660
#
# Epoch 00023: val_accuracy did not improve from 0.79531
# Epoch 24/25
# 80/80 [==============================] - 97s 1s/step - loss: 0.4008 - accuracy: 0.8203 - val_loss: 0.5944 - val_accuracy: 0.7750
#
# Epoch 00024: val_accuracy did not improve from 0.79531
# Epoch 25/25
# 80/80 [==============================] - 86s 1s/step - loss: 0.4036 - accuracy: 0.8176 - val_loss: 0.2393 - val_accuracy: 0.7859
#
# Epoch 00025: val_accuracy did not improve from 0.79531

# %%
seq.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30752)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               3936384
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 3,937,409
# Trainable params: 3,937,409
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = seq.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
    print('dog')
else:
    prediction = 'cat'
    print('cat')
# Out:
# dog

# %%
image.load_img('dataset/single_prediction/cat_or_dog_1.jpg',target_size=(720,720))
# Out:
# <PIL.Image.Image image mode=RGB size=720x720 at 0x202A1333C48>

# %%
from keras.models import load_model
seq=load_model("weights-improvement.hdf5")

# %%
seq.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 62, 62, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30752)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               3936384
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 3,937,409
# Trainable params: 3,937,409
# Non-trainable params: 0
# _________________________________________________________________
